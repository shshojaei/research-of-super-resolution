# %% [markdown]
# <a href="https://colab.research.google.com/github/shshojaei/research-of-super-resolution/blob/main/EDSR_my_mae.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, shutil
from google.colab import drive
drive.mount('/content/drive')
# !ls 'drive/MyDrive/Colab Notebooks/EDSR'
# Out:
# Mounted at /content/drive
# EDSR_Evaluation  EDSR_my_mae.ipynb  EDSR_x2.h5

# %% [markdown]
# # **Imports**

# %%
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import layers

from keras.applications.vgg19 import VGG19
from keras.models import Sequential

AUTOTUNE = tf.data.AUTOTUNE #for data augmentation

# %% [markdown]
# ## **prepare dataset**

# %%
# Download DIV2K from TF Datasets
# Using bicubic 4x degradation type
div2k_data = tfds.image.Div2k(config="bicubic_x4")
div2k_data.download_and_prepare()

# Taking train data from div2k_data object
train = div2k_data.as_dataset(split="train", as_supervised=True)
train_cache = train.cache()
# Validation data
val = div2k_data.as_dataset(split="validation", as_supervised=True)
val_cache = val.cache()
# Out:
# Downloading and preparing dataset div2k/bicubic_x4/2.0.0 (download: 3.97 GiB, generated: Unknown size, total: 3.97 GiB) to /root/tensorflow_datasets/div2k/bicubic_x4/2.0.0...
# EXTRACTING {'train_lr_url': 'https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_LR_bicubic_X4.zip', 'valid_lr_url': 'https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_LR_bicubic_X4.zip', 'train_hr_url': 'https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip', 'valid_hr_url': 'https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_HR.zip'}
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/div2k/bicubic_x4/2.0.0.incomplete8NJW7K/div2k-train.tfrecord
#   0%|          | 0/800 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/div2k/bicubic_x4/2.0.0.incomplete8NJW7K/div2k-validation.tfrecord
#   0%|          | 0/100 [00:00<?, ? examples/s]
# Dataset div2k downloaded and prepared to /root/tensorflow_datasets/div2k/bicubic_x4/2.0.0. Subsequent calls will reuse this data.

# %% [markdown]
# ## **image pre-processing**
#
#
# *   batch size

# %%
def flip_left_right(lowres_img, highres_img):
    """Flips Images to left and right."""

    # Outputs random values from a uniform distribution in between 0 to 1
    rn = tf.random.uniform(shape=(), maxval=1)
    # If rn is less than 0.5 it returns original lowres_img and highres_img
    # If rn is greater than 0.5 it returns flipped image
    return tf.cond(
        rn < 0.5,
        lambda: (lowres_img, highres_img),
        lambda: (
            tf.image.flip_left_right(lowres_img),
            tf.image.flip_left_right(highres_img),
        ),
    )


def random_rotate(lowres_img, highres_img):
    """Rotates Images by 90 degrees."""

    # Outputs random values from uniform distribution in between 0 to 4
    rn = tf.random.uniform(shape=(), maxval=4, dtype=tf.int32)
    # Here rn signifies number of times the image(s) are rotated by 90 degrees
    return tf.image.rot90(lowres_img, rn), tf.image.rot90(highres_img, rn)


def random_crop(lowres_img, highres_img, hr_crop_size=96, scale=4):
    """Crop images.

    low resolution images: 24x24
    hight resolution images: 96x96
    """
    lowres_crop_size = hr_crop_size // scale  # 96//4=24
    lowres_img_shape = tf.shape(lowres_img)[:2]  # (height,width)

    lowres_width = tf.random.uniform(
        shape=(), maxval=lowres_img_shape[1] - lowres_crop_size + 1, dtype=tf.int32
    )
    lowres_height = tf.random.uniform(
        shape=(), maxval=lowres_img_shape[0] - lowres_crop_size + 1, dtype=tf.int32
    )

    highres_width = lowres_width * scale
    highres_height = lowres_height * scale

    lowres_img_cropped = lowres_img[
        lowres_height : lowres_height + lowres_crop_size,
        lowres_width : lowres_width + lowres_crop_size,
    ]  # 24x24
    highres_img_cropped = highres_img[
        highres_height : highres_height + hr_crop_size,
        highres_width : highres_width + hr_crop_size,
    ]  # 96x96

    return lowres_img_cropped, highres_img_cropped

# %%
def dataset_object(dataset_cache, training=True):

    ds = dataset_cache
    ds = ds.map(
        lambda lowres, highres: random_crop(lowres, highres, scale=4),
        num_parallel_calls=AUTOTUNE,
    )

    if training:
        ds = ds.map(random_rotate, num_parallel_calls=AUTOTUNE)
        ds = ds.map(flip_left_right, num_parallel_calls=AUTOTUNE)
    # Batching Data
    ds = ds.batch(16)

    if training:
        # Repeating Data, so that cardinality if dataset becomes infinte
        ds = ds.repeat()
    # prefetching allows later images to be prepared while the current image is being processed
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds


train_ds = dataset_object(train_cache, training=True)
val_ds = dataset_object(val_cache, training=False)

# %%
#visualize a few sample images

lowres, highres = next(iter(train_ds))

# Hight Resolution Images
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(highres[i].numpy().astype("uint8"))
    plt.title(highres[i].shape)
    plt.axis("off")

# Low Resolution Images
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(lowres[i].numpy().astype("uint8"))
    plt.title(lowres[i].shape)
    plt.axis("off")

# %% [markdown]
# ## **architecture** (method)
#
#
# *   scale

# %%
# Residual Block
def ResBlock(inputs):
    x = layers.Conv2D(64, 3, padding="same", activation="relu")(inputs)
    x = layers.Conv2D(64, 3, padding="same")(x)
    x = layers.Add()([inputs, x])
    return x

# %%
# Upsampling Block
def Upsampling(inputs, factor=2, **kwargs):
    x = layers.Conv2D(64 * (factor ** 2), 3, padding="same", **kwargs)(inputs)
    x = tf.nn.depth_to_space(x, block_size=factor)
    x = layers.Conv2D(64 * (factor ** 2), 3, padding="same", **kwargs)(x)
    x = tf.nn.depth_to_space(x, block_size=factor)
    return x

# %%
class EDSRModel(tf.keras.Model):
    def train_step(self, data):
        # Unpack the data. Its structure depends on your model and
        # on what you pass to `fit()`.
        x, y = data

        with tf.GradientTape() as tape:
            y_pred = self(x, training=True)  # Forward pass
            # Compute the loss value
            # (the loss function is configured in `compile()`)
            loss = self.compiled_loss(y, y_pred, regularization_losses=self.losses)

        # Compute gradients
        
        trainable_vars = self.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))
        # Update metrics (includes the metric that tracks the loss)
        self.compiled_metrics.update_state(y, y_pred)
        # Return a dict mapping metric names to current value
        return {m.name: m.result() for m in self.metrics}

    def predict_step(self, x):
        # Adding dummy dimension using tf.expand_dims and converting to float32 using tf.cast
        x = tf.cast(tf.expand_dims(x, axis=0), tf.float32)
        # Passing low resolution image to model
        super_resolution_img = self(x, training=False)
        # Clips the tensor from min(0) to max(255)
        super_resolution_img = tf.clip_by_value(super_resolution_img, 0, 255)
        # Rounds the values of a tensor to the nearest integer
        super_resolution_img = tf.round(super_resolution_img)
        # Removes dimensions of size 1 from the shape of a tensor and converting to uint8
        super_resolution_img = tf.squeeze(
            tf.cast(super_resolution_img, tf.uint8), axis=0
        )
        return super_resolution_img


def make_model(num_filters, num_of_residual_blocks):
    # Flexible Inputs to input_layer
    input_layer = layers.Input(shape=(None, None, 3))
    # Scaling Pixel Values
    x = layers.Rescaling(scale=1.0 / 255)(input_layer)
    x = x_new = layers.Conv2D(num_filters, 3, padding="same")(x)

    # 16 residual blocks
    for _ in range(num_of_residual_blocks):
        x_new = ResBlock(x_new)

    x_new = layers.Conv2D(num_filters, 3, padding="same")(x_new)
    x = layers.Add()([x, x_new])

    x = Upsampling(x)
    x = layers.Conv2D(3, 3, padding="same")(x)

    output_layer = layers.Rescaling(scale=255)(x)
    return EDSRModel(input_layer, output_layer)


model = make_model(num_filters=64, num_of_residual_blocks=16)

# %%
model.summary()
# Out:
# Model: "edsr_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  rescaling (Rescaling)          (None, None, None,   0           ['input_1[0][0]']
#                                 3)
#
#  conv2d (Conv2D)                (None, None, None,   1792        ['rescaling[0][0]']
#                                 64)
#
#  conv2d_1 (Conv2D)              (None, None, None,   36928       ['conv2d[0][0]']
#                                 64)
#
#  conv2d_2 (Conv2D)              (None, None, None,   36928       ['conv2d_1[0][0]']
#                                 64)
#
#  add (Add)                      (None, None, None,   0           ['conv2d[0][0]',
#                                 64)                               'conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, None, None,   36928       ['add[0][0]']
#                                 64)
#
#  conv2d_4 (Conv2D)              (None, None, None,   36928       ['conv2d_3[0][0]']
#                                 64)
#
#  add_1 (Add)                    (None, None, None,   0           ['add[0][0]',
#                                 64)                               'conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, None, None,   36928       ['add_1[0][0]']
#                                 64)
#
#  conv2d_6 (Conv2D)              (None, None, None,   36928       ['conv2d_5[0][0]']
#                                 64)
#
#  add_2 (Add)                    (None, None, None,   0           ['add_1[0][0]',
#                                 64)                               'conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, None, None,   36928       ['add_2[0][0]']
#                                 64)
#
#  conv2d_8 (Conv2D)              (None, None, None,   36928       ['conv2d_7[0][0]']
#                                 64)
#
#  add_3 (Add)                    (None, None, None,   0           ['add_2[0][0]',
#                                 64)                               'conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, None, None,   36928       ['add_3[0][0]']
#                                 64)
#
#  conv2d_10 (Conv2D)             (None, None, None,   36928       ['conv2d_9[0][0]']
#                                 64)
#
#  add_4 (Add)                    (None, None, None,   0           ['add_3[0][0]',
#                                 64)                               'conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, None, None,   36928       ['add_4[0][0]']
#                                 64)
#
#  conv2d_12 (Conv2D)             (None, None, None,   36928       ['conv2d_11[0][0]']
#                                 64)
#
#  add_5 (Add)                    (None, None, None,   0           ['add_4[0][0]',
#                                 64)                               'conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, None, None,   36928       ['add_5[0][0]']
#                                 64)
#
#  conv2d_14 (Conv2D)             (None, None, None,   36928       ['conv2d_13[0][0]']
#                                 64)
#
#  add_6 (Add)                    (None, None, None,   0           ['add_5[0][0]',
#                                 64)                               'conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, None, None,   36928       ['add_6[0][0]']
#                                 64)
#
#  conv2d_16 (Conv2D)             (None, None, None,   36928       ['conv2d_15[0][0]']
#                                 64)
#
#  add_7 (Add)                    (None, None, None,   0           ['add_6[0][0]',
#                                 64)                               'conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, None, None,   36928       ['add_7[0][0]']
#                                 64)
#
#  conv2d_18 (Conv2D)             (None, None, None,   36928       ['conv2d_17[0][0]']
#                                 64)
#
#  add_8 (Add)                    (None, None, None,   0           ['add_7[0][0]',
#                                 64)                               'conv2d_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, None, None,   36928       ['add_8[0][0]']
#                                 64)
#
#  conv2d_20 (Conv2D)             (None, None, None,   36928       ['conv2d_19[0][0]']
#                                 64)
#
#  add_9 (Add)                    (None, None, None,   0           ['add_8[0][0]',
#                                 64)                               'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, None, None,   36928       ['add_9[0][0]']
#                                 64)
#
#  conv2d_22 (Conv2D)             (None, None, None,   36928       ['conv2d_21[0][0]']
#                                 64)
#
#  add_10 (Add)                   (None, None, None,   0           ['add_9[0][0]',
#                                 64)                               'conv2d_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, None, None,   36928       ['add_10[0][0]']
#                                 64)
#
#  conv2d_24 (Conv2D)             (None, None, None,   36928       ['conv2d_23[0][0]']
#                                 64)
#
#  add_11 (Add)                   (None, None, None,   0           ['add_10[0][0]',
#                                 64)                               'conv2d_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, None, None,   36928       ['add_11[0][0]']
#                                 64)
#
#  conv2d_26 (Conv2D)             (None, None, None,   36928       ['conv2d_25[0][0]']
#                                 64)
#
#  add_12 (Add)                   (None, None, None,   0           ['add_11[0][0]',
#                                 64)                               'conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, None, None,   36928       ['add_12[0][0]']
#                                 64)
#
#  conv2d_28 (Conv2D)             (None, None, None,   36928       ['conv2d_27[0][0]']
#                                 64)
#
#  add_13 (Add)                   (None, None, None,   0           ['add_12[0][0]',
#                                 64)                               'conv2d_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, None, None,   36928       ['add_13[0][0]']
#                                 64)
#
#  conv2d_30 (Conv2D)             (None, None, None,   36928       ['conv2d_29[0][0]']
#                                 64)
#
#  add_14 (Add)                   (None, None, None,   0           ['add_13[0][0]',
#                                 64)                               'conv2d_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, None, None,   36928       ['add_14[0][0]']
#                                 64)
#
#  conv2d_32 (Conv2D)             (None, None, None,   36928       ['conv2d_31[0][0]']
#                                 64)
#
#  add_15 (Add)                   (None, None, None,   0           ['add_14[0][0]',
#                                 64)                               'conv2d_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, None, None,   36928       ['add_15[0][0]']
#                                 64)
#
#  add_16 (Add)                   (None, None, None,   0           ['conv2d[0][0]',
#                                 64)                               'conv2d_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, None, None,   147712      ['add_16[0][0]']
#                                 256)
#
#  tf.nn.depth_to_space (TFOpLamb  (None, None, None,   0          ['conv2d_34[0][0]']
#  da)                            64)
#
#  conv2d_35 (Conv2D)             (None, None, None,   147712      ['tf.nn.depth_to_space[0][0]']
#                                 256)
#
#  tf.nn.depth_to_space_1 (TFOpLa  (None, None, None,   0          ['conv2d_35[0][0]']
#  mbda)                          64)
#
#  conv2d_36 (Conv2D)             (None, None, None,   1731        ['tf.nn.depth_to_space_1[0][0]']
#                                 3)
#
#  rescaling_1 (Rescaling)        (None, None, None,   0           ['conv2d_36[0][0]']
#                                 3)
#
# ==================================================================================================
# Total params: 1,517,571
# Trainable params: 1,517,571
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## **Training**
#
#
# *   Optimizer
# *   learning rate
# *   loss function
# *   epochs

# %%
# Using adam optimizer with initial learning rate as 1e-4, changing learning rate after 5000 steps to 5e-5
optimizer_ = keras.optimizers.Adam(
    learning_rate=keras.optimizers.schedules.PiecewiseConstantDecay(
        boundaries=[5000], values=[1e-4, 5e-5]
    )
)

# %%
print(tf. __version__)
# Out:
# 2.8.2

# %%
import keras.backend as K

def my_mae(y_true, y_pred):
  #convert Tensorflow tensor to numpy

  #Experiment1
  #y_true = y_true.numpy()
  #y_pred = y_pred.numpy()

  #Experiment2
  #y_true = tf.make_ndarray(y_true)
  #y_pred = tf.make_ndarray(y_pred)

  #Experiment3
  #y_true = tf.keras.preprocessing.image.array_to_img(y_true)
  #y_pred = tf.keras.preprocessing.image.array_to_img(y_pred)

  #Experiment4
  #y_true = keras.backend.eval(y_true)
  #y_pred = keras.backend.eval(y_pred)

  

  y_true = K.flatten(y_true)
  y_pred = K.flatten(y_pred)

  #assume RGB image and convert all integer values to float
  #y_true_data = y_true.astype(float)
  #y_pred_data = y_pred.astype(float)

  y_true = tf.cast( y_true, 'float32')
  y_pred = tf.cast( y_pred, 'float32')


    
  #diff = y_pred_data - y_true_data
  #diff = diff.flatten('C') #need ot flatten so computations can be done

  #diff = y_pred_data - y_true_data

    
  #return np.average(np.abs(diff), axis=0)
  return K.mean(K.abs(y_pred - y_true), axis=-1)

# %%
def PSNR(super_resolution, high_resolution):
  #Compute the peak signal-to-noise ratio, measures quality of image.
  # Max value of pixel is 255
  psnr_value = tf.image.psnr(high_resolution, super_resolution, max_val=255)[0]
  return psnr_value

# %%
model.compile(optimizer=optimizer_ , loss=my_mae , metrics=[PSNR])

# Training for more epochs will improve results
history_my_mae = model.fit(train_ds, epochs=100, steps_per_epoch=200, validation_data=val_ds)
# Out:
# Epoch 1/100
# 200/200 [==============================] - 99s 380ms/step - loss: 25.7794 - PSNR: 19.8925 - val_loss: 13.5443 - val_PSNR: 21.4246
# Epoch 2/100
# 200/200 [==============================] - 7s 34ms/step - loss: 12.4972 - PSNR: 25.7323 - val_loss: 10.8335 - val_PSNR: 24.9176
# Epoch 3/100
# 200/200 [==============================] - 7s 34ms/step - loss: 10.4723 - PSNR: 26.9404 - val_loss: 10.4333 - val_PSNR: 22.5295
# Epoch 4/100
# 200/200 [==============================] - 7s 34ms/step - loss: 9.8960 - PSNR: 27.3123 - val_loss: 8.8267 - val_PSNR: 27.7050
# Epoch 5/100
# 200/200 [==============================] - 7s 34ms/step - loss: 9.3749 - PSNR: 29.0612 - val_loss: 8.2789 - val_PSNR: 26.1195
# Epoch 6/100
# 200/200 [==============================] - 7s 36ms/step - loss: 8.9068 - PSNR: 30.0576 - val_loss: 8.7362 - val_PSNR: 26.0951
# Epoch 7/100
# 200/200 [==============================] - 8s 40ms/step - loss: 8.5485 - PSNR: 29.2623 - val_loss: 8.4941 - val_PSNR: 29.6013
# Epoch 8/100
# 200/200 [==============================] - 7s 34ms/step - loss: 8.5892 - PSNR: 29.4713 - val_loss: 7.9948 - val_PSNR: 30.9638
# Epoch 9/100
# 200/200 [==============================] - 7s 34ms/step - loss: 8.3007 - PSNR: 30.2566 - val_loss: 7.6166 - val_PSNR: 30.9151
# Epoch 10/100
# 200/200 [==============================] - 7s 34ms/step - loss: 8.1606 - PSNR: 29.9800 - val_loss: 7.8194 - val_PSNR: 32.4478
# Epoch 11/100
# 200/200 [==============================] - 7s 34ms/step - loss: 8.2412 - PSNR: 29.6722 - val_loss: 8.8272 - val_PSNR: 31.3030
# Epoch 12/100
# 200/200 [==============================] - 7s 34ms/step - loss: 8.1763 - PSNR: 29.0817 - val_loss: 7.5029 - val_PSNR: 28.3477
# Epoch 13/100
# 200/200 [==============================] - 7s 34ms/step - loss: 8.0404 - PSNR: 31.1325 - val_loss: 8.0817 - val_PSNR: 35.0637
# Epoch 14/100
# 200/200 [==============================] - 7s 34ms/step - loss: 8.0491 - PSNR: 30.7556 - val_loss: 6.6585 - val_PSNR: 32.7299
# Epoch 15/100
# 200/200 [==============================] - 8s 38ms/step - loss: 8.0138 - PSNR: 30.4429 - val_loss: 7.8459 - val_PSNR: 34.2046
# Epoch 16/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.9449 - PSNR: 30.7028 - val_loss: 7.5084 - val_PSNR: 31.4992
# Epoch 17/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.8031 - PSNR: 31.2150 - val_loss: 7.7205 - val_PSNR: 29.3209
# Epoch 18/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.7420 - PSNR: 31.0702 - val_loss: 7.8566 - val_PSNR: 32.9549
# Epoch 19/100
# 200/200 [==============================] - 7s 34ms/step - loss: 7.7979 - PSNR: 30.6936 - val_loss: 7.7650 - val_PSNR: 29.5608
# Epoch 20/100
# 200/200 [==============================] - 7s 34ms/step - loss: 7.8496 - PSNR: 30.4522 - val_loss: 7.6283 - val_PSNR: 29.9490
# Epoch 21/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.6746 - PSNR: 32.0130 - val_loss: 6.8480 - val_PSNR: 29.7835
# Epoch 22/100
# 200/200 [==============================] - 7s 36ms/step - loss: 7.7092 - PSNR: 31.3082 - val_loss: 7.4699 - val_PSNR: 32.9717
# Epoch 23/100
# 200/200 [==============================] - 7s 36ms/step - loss: 7.5464 - PSNR: 31.8944 - val_loss: 8.1319 - val_PSNR: 29.8808
# Epoch 24/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.4502 - PSNR: 31.1680 - val_loss: 7.5996 - val_PSNR: 27.4634
# Epoch 25/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.6406 - PSNR: 30.8002 - val_loss: 7.0223 - val_PSNR: 30.7793
# Epoch 26/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.4713 - PSNR: 31.9224 - val_loss: 7.4957 - val_PSNR: 28.6034
# Epoch 27/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.3910 - PSNR: 31.3096 - val_loss: 7.9395 - val_PSNR: 27.2694
# Epoch 28/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.5326 - PSNR: 31.3238 - val_loss: 7.6519 - val_PSNR: 29.1146
# Epoch 29/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.5162 - PSNR: 31.2865 - val_loss: 7.7533 - val_PSNR: 27.8308
# Epoch 30/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.3168 - PSNR: 31.8176 - val_loss: 7.9115 - val_PSNR: 28.6361
# Epoch 31/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.3362 - PSNR: 31.0544 - val_loss: 7.7994 - val_PSNR: 29.8950
# Epoch 32/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.3774 - PSNR: 31.8272 - val_loss: 7.7221 - val_PSNR: 27.0193
# Epoch 33/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.2562 - PSNR: 32.0322 - val_loss: 6.8638 - val_PSNR: 34.7112
# Epoch 34/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.3266 - PSNR: 32.5286 - val_loss: 6.7833 - val_PSNR: 31.6534
# Epoch 35/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.2696 - PSNR: 31.6635 - val_loss: 6.5302 - val_PSNR: 31.6790
# Epoch 36/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.3523 - PSNR: 31.3546 - val_loss: 6.6028 - val_PSNR: 35.7418
# Epoch 37/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.4239 - PSNR: 32.6266 - val_loss: 6.5069 - val_PSNR: 28.9687
# Epoch 38/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.3653 - PSNR: 32.0825 - val_loss: 7.3639 - val_PSNR: 30.1513
# Epoch 39/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.2586 - PSNR: 32.5501 - val_loss: 7.4645 - val_PSNR: 31.3282
# Epoch 40/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.2702 - PSNR: 31.3551 - val_loss: 9.3216 - val_PSNR: 27.4529
# Epoch 41/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.3895 - PSNR: 31.6780 - val_loss: 7.4929 - val_PSNR: 33.9003
# Epoch 42/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0781 - PSNR: 31.6847 - val_loss: 7.3489 - val_PSNR: 28.9091
# Epoch 43/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.1932 - PSNR: 32.3271 - val_loss: 7.7196 - val_PSNR: 29.0236
# Epoch 44/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.2352 - PSNR: 32.7222 - val_loss: 6.6238 - val_PSNR: 28.6550
# Epoch 45/100
# 200/200 [==============================] - 8s 38ms/step - loss: 7.2280 - PSNR: 33.1449 - val_loss: 6.6838 - val_PSNR: 33.3401
# Epoch 46/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0944 - PSNR: 32.0733 - val_loss: 7.0329 - val_PSNR: 26.1824
# Epoch 47/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.2215 - PSNR: 32.5044 - val_loss: 7.7323 - val_PSNR: 31.8177
# Epoch 48/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.3146 - PSNR: 32.1623 - val_loss: 7.3335 - val_PSNR: 31.9587
# Epoch 49/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0948 - PSNR: 32.2956 - val_loss: 6.1634 - val_PSNR: 37.6785
# Epoch 50/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.4476 - PSNR: 32.1651 - val_loss: 6.9463 - val_PSNR: 31.6377
# Epoch 51/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0421 - PSNR: 32.4821 - val_loss: 7.0855 - val_PSNR: 31.0992
# Epoch 52/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0974 - PSNR: 32.2688 - val_loss: 6.9046 - val_PSNR: 32.0853
# Epoch 53/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.1472 - PSNR: 31.6097 - val_loss: 7.0244 - val_PSNR: 35.1000
# Epoch 54/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.3189 - PSNR: 31.9290 - val_loss: 7.0877 - val_PSNR: 28.5087
# Epoch 55/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.1962 - PSNR: 32.9215 - val_loss: 7.2307 - val_PSNR: 28.6318
# Epoch 56/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.2536 - PSNR: 32.4230 - val_loss: 7.0586 - val_PSNR: 34.8385
# Epoch 57/100
# 200/200 [==============================] - 7s 35ms/step - loss: 6.9358 - PSNR: 33.3259 - val_loss: 7.8617 - val_PSNR: 35.5827
# Epoch 58/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.1794 - PSNR: 31.9238 - val_loss: 7.3040 - val_PSNR: 31.5122
# Epoch 59/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0757 - PSNR: 32.2257 - val_loss: 7.2240 - val_PSNR: 29.7055
# Epoch 60/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.1759 - PSNR: 32.7620 - val_loss: 6.5755 - val_PSNR: 33.4655
# Epoch 61/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0169 - PSNR: 32.7948 - val_loss: 7.9540 - val_PSNR: 31.1574
# Epoch 62/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.1067 - PSNR: 31.9104 - val_loss: 7.2773 - val_PSNR: 30.4792
# Epoch 63/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0380 - PSNR: 32.9522 - val_loss: 6.5279 - val_PSNR: 33.3256
# Epoch 64/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.2478 - PSNR: 32.2481 - val_loss: 7.5981 - val_PSNR: 34.0266
# Epoch 65/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0777 - PSNR: 31.2817 - val_loss: 7.0273 - val_PSNR: 30.2568
# Epoch 66/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.1589 - PSNR: 32.0761 - val_loss: 7.0371 - val_PSNR: 27.7589
# Epoch 67/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0552 - PSNR: 32.4550 - val_loss: 6.9461 - val_PSNR: 26.7877
# Epoch 68/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0177 - PSNR: 32.3235 - val_loss: 6.4300 - val_PSNR: 28.4537
# Epoch 69/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0893 - PSNR: 32.6828 - val_loss: 6.9435 - val_PSNR: 27.2959
# Epoch 70/100
# 200/200 [==============================] - 8s 41ms/step - loss: 7.1186 - PSNR: 32.4104 - val_loss: 7.1952 - val_PSNR: 29.0409
# Epoch 71/100
# 200/200 [==============================] - 8s 38ms/step - loss: 7.0898 - PSNR: 32.3907 - val_loss: 8.5735 - val_PSNR: 29.1515
# Epoch 72/100
# 200/200 [==============================] - 7s 35ms/step - loss: 6.8307 - PSNR: 32.9860 - val_loss: 6.7623 - val_PSNR: 36.1434
# Epoch 73/100
# 200/200 [==============================] - 7s 36ms/step - loss: 6.9550 - PSNR: 32.8466 - val_loss: 7.5752 - val_PSNR: 30.5194
# Epoch 74/100
# 200/200 [==============================] - 8s 38ms/step - loss: 6.8621 - PSNR: 33.1806 - val_loss: 6.6631 - val_PSNR: 36.8830
# Epoch 75/100
# 200/200 [==============================] - 7s 35ms/step - loss: 6.9667 - PSNR: 32.1647 - val_loss: 7.1429 - val_PSNR: 29.4452
# Epoch 76/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0547 - PSNR: 31.7025 - val_loss: 7.1375 - val_PSNR: 32.1113
# Epoch 77/100
# 200/200 [==============================] - 7s 36ms/step - loss: 6.9787 - PSNR: 32.3638 - val_loss: 6.5181 - val_PSNR: 28.7557
# Epoch 78/100
# 200/200 [==============================] - 7s 36ms/step - loss: 6.9352 - PSNR: 31.8357 - val_loss: 7.2495 - val_PSNR: 29.4731
# Epoch 79/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.1206 - PSNR: 31.9546 - val_loss: 7.3341 - val_PSNR: 34.7655
# Epoch 80/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0462 - PSNR: 33.1872 - val_loss: 6.7726 - val_PSNR: 30.6168
# Epoch 81/100
# 200/200 [==============================] - 7s 36ms/step - loss: 6.9444 - PSNR: 32.6231 - val_loss: 6.5487 - val_PSNR: 32.0200
# Epoch 82/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0951 - PSNR: 31.3719 - val_loss: 7.4245 - val_PSNR: 30.2905
# Epoch 83/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0577 - PSNR: 32.5506 - val_loss: 6.5119 - val_PSNR: 35.8218
# Epoch 84/100
# 200/200 [==============================] - 7s 35ms/step - loss: 6.9741 - PSNR: 33.6313 - val_loss: 7.7053 - val_PSNR: 28.2311
# Epoch 85/100
# 200/200 [==============================] - 7s 35ms/step - loss: 6.9856 - PSNR: 32.6360 - val_loss: 6.6764 - val_PSNR: 31.5639
# Epoch 86/100
# 200/200 [==============================] - 7s 35ms/step - loss: 6.8403 - PSNR: 32.1940 - val_loss: 6.8742 - val_PSNR: 29.6141
# Epoch 87/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0368 - PSNR: 33.0535 - val_loss: 6.6232 - val_PSNR: 32.1915
# Epoch 88/100
# 200/200 [==============================] - 7s 35ms/step - loss: 6.8451 - PSNR: 32.0846 - val_loss: 6.7867 - val_PSNR: 34.3512
# Epoch 89/100
# 200/200 [==============================] - 7s 36ms/step - loss: 7.1298 - PSNR: 31.6808 - val_loss: 6.6236 - val_PSNR: 31.7265
# Epoch 90/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0159 - PSNR: 32.9133 - val_loss: 6.8599 - val_PSNR: 27.8304
# Epoch 91/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.1004 - PSNR: 32.8584 - val_loss: 7.0547 - val_PSNR: 33.6653
# Epoch 92/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0687 - PSNR: 31.9135 - val_loss: 6.9388 - val_PSNR: 33.3949
# Epoch 93/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0569 - PSNR: 32.1197 - val_loss: 6.8333 - val_PSNR: 36.8431
# Epoch 94/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0571 - PSNR: 32.7933 - val_loss: 6.5936 - val_PSNR: 29.9515
# Epoch 95/100
# 200/200 [==============================] - 7s 35ms/step - loss: 6.8841 - PSNR: 32.2076 - val_loss: 7.3732 - val_PSNR: 33.6248
# Epoch 96/100
# 200/200 [==============================] - 7s 35ms/step - loss: 6.8414 - PSNR: 32.4691 - val_loss: 6.9042 - val_PSNR: 32.6264
# Epoch 97/100
# 200/200 [==============================] - 7s 35ms/step - loss: 6.9901 - PSNR: 31.4284 - val_loss: 7.2075 - val_PSNR: 28.9051
# Epoch 98/100
# 200/200 [==============================] - 7s 36ms/step - loss: 6.9831 - PSNR: 32.5737 - val_loss: 6.9243 - val_PSNR: 33.4549
# Epoch 99/100
# 200/200 [==============================] - 7s 36ms/step - loss: 6.9001 - PSNR: 32.4724 - val_loss: 7.5816 - val_PSNR: 28.8694
# Epoch 100/100
# 200/200 [==============================] - 7s 35ms/step - loss: 7.0072 - PSNR: 32.7664 - val_loss: 6.9904 - val_PSNR: 36.6343

# %%
model.save('drive/MyDrive/Colab Notebooks/EDSR/model_my_mae.h5')

# %%
model = keras.models.load_model('drive/MyDrive/Colab Notebooks/model_my_mae.h5')
