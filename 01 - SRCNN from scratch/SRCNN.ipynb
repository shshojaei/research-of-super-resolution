# %% [markdown]
# references:
#
# 1- https://github.com/kunal-visoulia/Image-Restoration-using-SRCNN#:~:text=The%20SRCNN%20is%20a%20deep,resolution%20to%20high%20resolution%20images.&text=To%20evaluate%20the%20performance%20of,squared%20error%20(MSE)%2C%20and
#
# 2- https://github.com/Data-Science-Community-SRM/1080-Pixels

# %%
import os, shutil
from google.colab import drive
drive.mount('/content/drive')
# !ls 'drive/MyDrive/Colab Notebooks/SRCNN'
# Out:
# Mounted at /content/drive
# LR  Set14  Set5  source  SRCNN.ipynb  weights.h5

# %%
import sys
import keras
import cv2
import numpy as np
import matplotlib.pyplot as plt
import skimage
import math
import os
import h5py

# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.optimizers import Adam
from skimage.metrics import structural_similarity as ssim
from matplotlib import pyplot as plt
import numpy as np
import math
import os

# python magic function, displays pyplot figures in the notebook instead of separate display window
# %matplotlib inline

# %%
#define a function for peak signal-to-noise ratio (PSNR)
def psnr(target,ref):#target image and refernce image
    
    #assume RGB image and convert all integer values to float
    target_data=target.astype(float)
    ref_data=ref.astype(float)
    
    diff=ref_data-target_data
    diff=diff.flatten('C')#need ot flatten so computations can be done
    
    rmse=math.sqrt(np.mean(diff**2.))#2. for float values
    
    return 20*math.log10(255./rmse)

# %%
#define function for mean squared error(MSE)
def mse(target,ref):
    # the MSE between the two images is the sum of the squared difference between the two images
    err=np.sum((target.astype('float')-ref.astype('float'))**2)
    err=err/float(target.shape[0]*target.shape[1])#divided by total number of pixels
    
    return err

# %%
# define function that combines all three image quality metrics
def compare_images(target,ref):
    scores=[]
    scores.append(psnr(target,ref))
    scores.append(mse(target,ref))
    scores.append(ssim(target,ref,multichannel=True))#multichannel so that it can handle 3Dor 3 channel images RGB/BGR 
    
    return scores

# %%
import os
import cv2

# prepare degraded images by introducing quality distortions resizing

def prepare_images(path, factor):
    
    # loop through the files in the directory
    for file in os.listdir(path):
        
        # open the file
        img = cv2.imread(path + '/' + file)
        
        # find old and new image dimensions
        h, w, c = img.shape
        new_height = int(h / factor)
        new_width = int(w / factor)
        
        # resize the image - down
        img = cv2.resize(img, (new_width, new_height), interpolation = cv2.INTER_LINEAR)
        #interploation are methods for resizing images;how do you go from image with 100px to 1000px 
        #bilinear interpolation
        
        # resize the image - up
        img = cv2.resize(img, (w, h), interpolation = cv2.INTER_LINEAR)
        
        # save the image
        print('Saving {}'.format(file))
        cv2.imwrite(r'drive/MyDrive/Colab Notebooks/SRCNN/LR/{}'.format(file), img)

# %%
prepare_images(r'drive/MyDrive/Colab Notebooks/SRCNN/source/',3)
#source folder has high resolution images that will be converted to low resoltion images to be used for SRCNN
# Out:
# Saving t13.png
# Saving t44.png
# Saving t56.png
# Saving tt24.png
# Saving tt5.png
# Saving t65.png
# Saving t30.png
# Saving tt22.png
# Saving t66.png
# Saving t52.png
# Saving tt13.png
# Saving tt18.png
# Saving t47.png
# Saving tt7.png
# Saving tt16.png
# Saving t63.png
# Saving tt10.png
# Saving t57.png
# Saving t33.png
# Saving t2.png
# Saving t8.png
# Saving t19.png
# Saving t29.png
# Saving t55.png
# Saving t24.png
# Saving t28.png
# Saving t18.png
# Saving t34.png
# Saving t37.png
# Saving t53.png
# Saving t48.png
# Saving t36.png
# Saving t49.png
# Saving t9.png
# Saving t1.png
# Saving t51.png
# Saving tt23.png
# Saving tt12.png
# Saving t62.png
# Saving t58.png
# Saving t45.png
# Saving t42.png
# Saving t3.png
# Saving t31.png
# Saving t27.png
# Saving t16.png
# Saving t21.png
# Saving tt9.png
# Saving t23.png
# Saving t15.png
# Saving t4.png
# Saving t32.png
# Saving t43.png
# Saving t20.png
# Saving tt14.png
# Saving t25.png
# Saving t35.png
# Saving tt8.png
# Saving tt1.png
# Saving tt4.png
# Saving tt17.png
# Saving t7.png
# Saving t39.png
# Saving t10.png
# Saving tt2.png
# Saving t6.png
# Saving t17.png
# Saving t12.png
# Saving t38.png
# Saving t11.png
# Saving tt19.png
# Saving tt27.png
# Saving t14.png
# Saving tt3.png
# Saving t46.png
# Saving tt26.png
# Saving t54.png
# Saving t59.png
# Saving tt6.png
# Saving tt25.png
# Saving t40.png
# Saving t50.png
# Saving t60.png
# Saving tt21.png
# Saving tt20.png
# Saving t64.png
# Saving t22.png
# Saving tt15.png
# Saving t26.png
# Saving t5.png
# Saving t61.png

# %%
xtrain_path=r'drive/MyDrive/Colab Notebooks/SRCNN/LR'
ytrain_path=r'drive/MyDrive/Colab Notebooks/SRCNN/source'

# %%
low_res_path=os.listdir(xtrain_path)
high_res_path=os.listdir(ytrain_path)

# %%
low_res_path[0]
# Out:
# 't13.png'

# %%
x_train_path=[]
y_train_path=[]
for i in range(0,len(low_res_path)):
    x_train_path.append(xtrain_path+"/"+low_res_path[i])
    y_train_path.append(ytrain_path+"/"+high_res_path[i])

# %%
x_train_path= sorted(x_train_path)
y_train_path=sorted(y_train_path)

# %%
Random_Crop = 30
Patch_size = 32
label_size = 20
conv_side = 6
scale = 2


def prepare_data(_path):
    nums = _path.__len__()

    data = np.zeros((nums * Random_Crop, 1, Patch_size, Patch_size), dtype=np.double)
    label = np.zeros((nums * Random_Crop, 1, label_size, label_size), dtype=np.double)

    for i in _path:
        name = i
        hr_img = cv2.imread(name, cv2.IMREAD_COLOR)
        shape = hr_img.shape

        hr_img = cv2.cvtColor(hr_img, cv2.COLOR_BGR2YCrCb)
        hr_img = hr_img[:, :, 0]

        # two resize operation to produce training data and labels
        lr_img = cv2.resize(hr_img, (shape[1] / scale, shape[0] / scale))
        lr_img = cv2.resize(lr_img, (shape[1], shape[0]))

        # produce Random_Crop random coordinate to crop training img
        Points_x = np.random.randint(0, min(shape[0], shape[1]) - Patch_size, Random_Crop)
        Points_y = np.random.randint(0, min(shape[0], shape[1]) - Patch_size, Random_Crop)

        for j in range(Random_Crop):
            lr_patch = lr_img[Points_x[j]: Points_x[j] + Patch_size, Points_y[j]: Points_y[j] + Patch_size]
            hr_patch = hr_img[Points_x[j]: Points_x[j] + Patch_size, Points_y[j]: Points_y[j] + Patch_size]

            lr_patch = lr_patch.astype(float) / 255.
            hr_patch = hr_patch.astype(float) / 255.

            data[i * Random_Crop + j, 0, :, :] = lr_patch
            label[i * Random_Crop + j, 0, :, :] = hr_patch[conv_side: -conv_side, conv_side: -conv_side]
            # cv2.imshow("lr", lr_patch)
            # cv2.imshow("hr", hr_patch)
            # cv2.waitKey(0)
    return data, label

# %%
BLOCK_STEP = 16
BLOCK_SIZE = 32


def prepare_crop_data(_path):
    nums = _path.__len__()

    data = []
    label = []

    for i in _path:
        name = i
        hr_img = cv2.imread(name, cv2.IMREAD_COLOR)
        hr_img = cv2.cvtColor(hr_img, cv2.COLOR_BGR2YCrCb)
        hr_img = hr_img[:, :, 0]
        shape = hr_img.shape

        # two resize operation to produce training data and labels
        lr_img = cv2.resize(hr_img, (shape[1] // scale, shape[0] // scale))
        lr_img = cv2.resize(lr_img, (shape[1], shape[0]))

        width_num = (shape[0] - (BLOCK_SIZE - BLOCK_STEP) * 2) // BLOCK_STEP
        height_num = (shape[1] - (BLOCK_SIZE - BLOCK_STEP) * 2) // BLOCK_STEP
        for k in range(width_num):
            for j in range(height_num):
                x = k * BLOCK_STEP
                y = j * BLOCK_STEP
                hr_patch = hr_img[x: x + BLOCK_SIZE, y: y + BLOCK_SIZE]
                lr_patch = lr_img[x: x + BLOCK_SIZE, y: y + BLOCK_SIZE]

                lr_patch = lr_patch.astype(float) / 255.
                hr_patch = hr_patch.astype(float) / 255.

                lr = np.zeros((1, Patch_size, Patch_size), dtype=np.double)
                hr = np.zeros((1, label_size, label_size), dtype=np.double)

                lr[0, :, :] = lr_patch
                hr[0, :, :] = hr_patch[conv_side: -conv_side, conv_side: -conv_side]

                data.append(lr)
                label.append(hr)

    data = np.array(data, dtype=float)
    label = np.array(label, dtype=float)
    return data, label

# %%
def write_hdf5(data, labels, output_filename):
    """
    This function is used to save image data and its label(s) to hdf5 file.
    output_file.h5,contain data and label
    """

    x = data.astype(np.float32)
    y = labels.astype(np.float32)

    with h5py.File(output_filename, 'w') as h:
        h.create_dataset('data', data=x, shape=x.shape)
        h.create_dataset('label', data=y, shape=y.shape)
        # h.create_dataset()

# %%
def read_training_data(file):
    with h5py.File(file, 'r') as hf:
        data = np.array(hf.get('data'))
        label = np.array(hf.get('label'))
        train_data = np.transpose(data, (0, 2, 3, 1))
        train_label = np.transpose(label, (0, 2, 3, 1))
        return train_data, train_label

# %%
traindata, trainlabel = prepare_crop_data(y_train_path)

# %%
srcnn=Sequential()
srcnn.add(Conv2D(filters=128, kernel_size = (9, 9), kernel_initializer='glorot_uniform',
                 activation='relu', padding='valid', use_bias=True, input_shape=(None,None,1)))
srcnn.add(Conv2D(filters=64, kernel_size = (3, 3), kernel_initializer='glorot_uniform',
                     activation='relu', padding='same', use_bias=True))
srcnn.add(Conv2D(filters=1, kernel_size = (5, 5), kernel_initializer='glorot_uniform',
                     activation='linear', padding='valid', use_bias=True))
adam = Adam(lr=0.0001)
srcnn.compile(optimizer=adam, loss='mean_squared_error', metrics=['mean_squared_error'])
srcnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, None, None, 128)   10496
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, None, 64)    73792
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, None, None, 1)     1601
# =================================================================
# Total params: 85,889
# Trainable params: 85,889
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
train_data = np.transpose(traindata, (0, 2, 3, 1))
train_label = np.transpose(trainlabel, (0, 2, 3, 1))
train_data.shape
# Out:
# (14901, 32, 32, 1)

# %%
model = srcnn.fit(train_data,train_label,batch_size=128,epochs=250,validation_split=0.2)
model.history
# Out:
# Epoch 1/250
# 94/94 [==============================] - 45s 21ms/step - loss: 0.0758 - mean_squared_error: 0.0758 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 2/250
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 3/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 4/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 9.2024e-04 - val_mean_squared_error: 9.2024e-04
# Epoch 5/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 8.7823e-04 - val_mean_squared_error: 8.7823e-04
# Epoch 6/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 8.5679e-04 - val_mean_squared_error: 8.5679e-04
# Epoch 7/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 8.3089e-04 - val_mean_squared_error: 8.3089e-04
# Epoch 8/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 8.1768e-04 - val_mean_squared_error: 8.1768e-04
# Epoch 9/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 8.0938e-04 - val_mean_squared_error: 8.0938e-04
# Epoch 10/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 7.9937e-04 - val_mean_squared_error: 7.9937e-04
# Epoch 11/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 8.2536e-04 - val_mean_squared_error: 8.2536e-04
# Epoch 12/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.8859e-04 - val_mean_squared_error: 7.8859e-04
# Epoch 13/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 7.8532e-04 - val_mean_squared_error: 7.8532e-04
# Epoch 14/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.7864e-04 - val_mean_squared_error: 7.7864e-04
# Epoch 15/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.7552e-04 - val_mean_squared_error: 7.7552e-04
# Epoch 16/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.7495e-04 - val_mean_squared_error: 7.7495e-04
# Epoch 17/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.6840e-04 - val_mean_squared_error: 7.6840e-04
# Epoch 18/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.6771e-04 - val_mean_squared_error: 7.6771e-04
# Epoch 19/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.6685e-04 - val_mean_squared_error: 7.6685e-04
# Epoch 20/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.6139e-04 - val_mean_squared_error: 7.6139e-04
# Epoch 21/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.6147e-04 - val_mean_squared_error: 7.6147e-04
# Epoch 22/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.5922e-04 - val_mean_squared_error: 7.5922e-04
# Epoch 23/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.5431e-04 - val_mean_squared_error: 7.5431e-04
# Epoch 24/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.4977e-04 - val_mean_squared_error: 7.4977e-04
# Epoch 25/250
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.5555e-04 - val_mean_squared_error: 7.5555e-04
# Epoch 26/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.7189e-04 - val_mean_squared_error: 7.7189e-04
# Epoch 27/250
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.4377e-04 - val_mean_squared_error: 7.4377e-04
# Epoch 28/250
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.4307e-04 - val_mean_squared_error: 7.4307e-04
# Epoch 29/250
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.5165e-04 - val_mean_squared_error: 7.5165e-04
# Epoch 30/250
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.4117e-04 - val_mean_squared_error: 7.4117e-04
# Epoch 31/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.4179e-04 - val_mean_squared_error: 7.4179e-04
# Epoch 32/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.3512e-04 - val_mean_squared_error: 7.3512e-04
# Epoch 33/250
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.3612e-04 - val_mean_squared_error: 7.3612e-04
# Epoch 34/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.3257e-04 - val_mean_squared_error: 7.3257e-04
# Epoch 35/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.2941e-04 - val_mean_squared_error: 7.2941e-04
# Epoch 36/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.3870e-04 - val_mean_squared_error: 7.3870e-04
# Epoch 37/250
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.2494e-04 - val_mean_squared_error: 7.2494e-04
# Epoch 38/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.2975e-04 - val_mean_squared_error: 7.2975e-04
# Epoch 39/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.2415e-04 - val_mean_squared_error: 7.2415e-04
# Epoch 40/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.2497e-04 - val_mean_squared_error: 7.2497e-04
# Epoch 41/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.2376e-04 - val_mean_squared_error: 7.2376e-04
# Epoch 42/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.1754e-04 - val_mean_squared_error: 7.1754e-04
# Epoch 43/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.1587e-04 - val_mean_squared_error: 7.1587e-04
# Epoch 44/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.2830e-04 - val_mean_squared_error: 7.2830e-04
# Epoch 45/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.1219e-04 - val_mean_squared_error: 7.1219e-04
# Epoch 46/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.1462e-04 - val_mean_squared_error: 7.1462e-04
# Epoch 47/250
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.3051e-04 - val_mean_squared_error: 7.3051e-04
# Epoch 48/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.1551e-04 - val_mean_squared_error: 7.1551e-04
# Epoch 49/250
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.2547e-04 - val_mean_squared_error: 7.2547e-04
# Epoch 50/250
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.0882e-04 - val_mean_squared_error: 7.0882e-04
# Epoch 51/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.1004e-04 - val_mean_squared_error: 7.1004e-04
# Epoch 52/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.0395e-04 - val_mean_squared_error: 7.0395e-04
# Epoch 53/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.0526e-04 - val_mean_squared_error: 7.0526e-04
# Epoch 54/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.0783e-04 - val_mean_squared_error: 7.0783e-04
# Epoch 55/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.0580e-04 - val_mean_squared_error: 7.0580e-04
# Epoch 56/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.0194e-04 - val_mean_squared_error: 7.0194e-04
# Epoch 57/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.0131e-04 - val_mean_squared_error: 7.0131e-04
# Epoch 58/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.0216e-04 - val_mean_squared_error: 7.0216e-04
# Epoch 59/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.0412e-04 - val_mean_squared_error: 7.0412e-04
# Epoch 60/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.9762e-04 - val_mean_squared_error: 6.9762e-04
# Epoch 61/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.3001e-04 - val_mean_squared_error: 7.3001e-04
# Epoch 62/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.9837e-04 - val_mean_squared_error: 6.9837e-04
# Epoch 63/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.9770e-04 - val_mean_squared_error: 6.9770e-04
# Epoch 64/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.9241e-04 - val_mean_squared_error: 6.9241e-04
# Epoch 65/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.8907e-04 - val_mean_squared_error: 6.8907e-04
# Epoch 66/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.8590e-04 - val_mean_squared_error: 6.8590e-04
# Epoch 67/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.8550e-04 - val_mean_squared_error: 6.8550e-04
# Epoch 68/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.9376e-04 - val_mean_squared_error: 6.9376e-04
# Epoch 69/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.8947e-04 - val_mean_squared_error: 6.8947e-04
# Epoch 70/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.8858e-04 - val_mean_squared_error: 6.8858e-04
# Epoch 71/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.0958e-04 - val_mean_squared_error: 7.0958e-04
# Epoch 72/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.8356e-04 - val_mean_squared_error: 6.8356e-04
# Epoch 73/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.8662e-04 - val_mean_squared_error: 6.8662e-04
# Epoch 74/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.8943e-04 - val_mean_squared_error: 6.8943e-04
# Epoch 75/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.8141e-04 - val_mean_squared_error: 6.8141e-04
# Epoch 76/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.7977e-04 - val_mean_squared_error: 6.7977e-04
# Epoch 77/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.8631e-04 - val_mean_squared_error: 6.8631e-04
# Epoch 78/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.7806e-04 - val_mean_squared_error: 6.7806e-04
# Epoch 79/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.7728e-04 - val_mean_squared_error: 6.7728e-04
# Epoch 80/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.8259e-04 - val_mean_squared_error: 6.8258e-04
# Epoch 81/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.8648e-04 - val_mean_squared_error: 6.8648e-04
# Epoch 82/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.9037e-04 - val_mean_squared_error: 6.9037e-04
# Epoch 83/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.7551e-04 - val_mean_squared_error: 6.7551e-04
# Epoch 84/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.7809e-04 - val_mean_squared_error: 6.7809e-04
# Epoch 85/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.7859e-04 - val_mean_squared_error: 6.7859e-04
# Epoch 86/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.7605e-04 - val_mean_squared_error: 6.7605e-04
# Epoch 87/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.7175e-04 - val_mean_squared_error: 6.7175e-04
# Epoch 88/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.9209e-04 - val_mean_squared_error: 6.9209e-04
# Epoch 89/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.7599e-04 - val_mean_squared_error: 6.7599e-04
# Epoch 90/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.7748e-04 - val_mean_squared_error: 6.7748e-04
# Epoch 91/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.6914e-04 - val_mean_squared_error: 6.6914e-04
# Epoch 92/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.6761e-04 - val_mean_squared_error: 6.6761e-04
# Epoch 93/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.6607e-04 - val_mean_squared_error: 6.6607e-04
# Epoch 94/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.8635e-04 - val_mean_squared_error: 6.8635e-04
# Epoch 95/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.7280e-04 - val_mean_squared_error: 6.7280e-04
# Epoch 96/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.6608e-04 - val_mean_squared_error: 6.6608e-04
# Epoch 97/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.7064e-04 - val_mean_squared_error: 6.7064e-04
# Epoch 98/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.6376e-04 - val_mean_squared_error: 6.6376e-04
# Epoch 99/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.6946e-04 - val_mean_squared_error: 6.6946e-04
# Epoch 100/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.7791e-04 - val_mean_squared_error: 6.7791e-04
# Epoch 101/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.6618e-04 - val_mean_squared_error: 6.6618e-04
# Epoch 102/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.6477e-04 - val_mean_squared_error: 6.6477e-04
# Epoch 103/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.6599e-04 - val_mean_squared_error: 6.6599e-04
# Epoch 104/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.6286e-04 - val_mean_squared_error: 6.6286e-04
# Epoch 105/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.6211e-04 - val_mean_squared_error: 6.6211e-04
# Epoch 106/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.6303e-04 - val_mean_squared_error: 6.6303e-04
# Epoch 107/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.6723e-04 - val_mean_squared_error: 6.6723e-04
# Epoch 108/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.6262e-04 - val_mean_squared_error: 6.6262e-04
# Epoch 109/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.6086e-04 - val_mean_squared_error: 6.6086e-04
# Epoch 110/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.6155e-04 - val_mean_squared_error: 6.6155e-04
# Epoch 111/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5805e-04 - val_mean_squared_error: 6.5805e-04
# Epoch 112/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5809e-04 - val_mean_squared_error: 6.5809e-04
# Epoch 113/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5552e-04 - val_mean_squared_error: 6.5552e-04
# Epoch 114/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.6145e-04 - val_mean_squared_error: 6.6145e-04
# Epoch 115/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.5805e-04 - val_mean_squared_error: 6.5805e-04
# Epoch 116/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5555e-04 - val_mean_squared_error: 6.5555e-04
# Epoch 117/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5660e-04 - val_mean_squared_error: 6.5660e-04
# Epoch 118/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5670e-04 - val_mean_squared_error: 6.5670e-04
# Epoch 119/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.6237e-04 - val_mean_squared_error: 6.6237e-04
# Epoch 120/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.6012e-04 - val_mean_squared_error: 6.6012e-04
# Epoch 121/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.6353e-04 - val_mean_squared_error: 6.6353e-04
# Epoch 122/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.7253e-04 - val_mean_squared_error: 6.7253e-04
# Epoch 123/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5449e-04 - val_mean_squared_error: 6.5449e-04
# Epoch 124/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5078e-04 - val_mean_squared_error: 6.5078e-04
# Epoch 125/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5426e-04 - val_mean_squared_error: 6.5426e-04
# Epoch 126/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.6063e-04 - val_mean_squared_error: 6.6063e-04
# Epoch 127/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5655e-04 - val_mean_squared_error: 6.5655e-04
# Epoch 128/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5255e-04 - val_mean_squared_error: 6.5255e-04
# Epoch 129/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4900e-04 - val_mean_squared_error: 6.4900e-04
# Epoch 130/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5806e-04 - val_mean_squared_error: 6.5806e-04
# Epoch 131/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5158e-04 - val_mean_squared_error: 6.5158e-04
# Epoch 132/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5104e-04 - val_mean_squared_error: 6.5104e-04
# Epoch 133/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5082e-04 - val_mean_squared_error: 6.5082e-04
# Epoch 134/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4887e-04 - val_mean_squared_error: 6.4887e-04
# Epoch 135/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4565e-04 - val_mean_squared_error: 6.4565e-04
# Epoch 136/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.7081e-04 - val_mean_squared_error: 6.7081e-04
# Epoch 137/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4579e-04 - val_mean_squared_error: 6.4579e-04
# Epoch 138/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5353e-04 - val_mean_squared_error: 6.5353e-04
# Epoch 139/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4596e-04 - val_mean_squared_error: 6.4596e-04
# Epoch 140/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4588e-04 - val_mean_squared_error: 6.4588e-04
# Epoch 141/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5887e-04 - val_mean_squared_error: 6.5887e-04
# Epoch 142/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5005e-04 - val_mean_squared_error: 6.5005e-04
# Epoch 143/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5871e-04 - val_mean_squared_error: 6.5871e-04
# Epoch 144/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5531e-04 - val_mean_squared_error: 6.5531e-04
# Epoch 145/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4466e-04 - val_mean_squared_error: 6.4466e-04
# Epoch 146/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4886e-04 - val_mean_squared_error: 6.4886e-04
# Epoch 147/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5327e-04 - val_mean_squared_error: 6.5327e-04
# Epoch 148/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4731e-04 - val_mean_squared_error: 6.4731e-04
# Epoch 149/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4365e-04 - val_mean_squared_error: 6.4365e-04
# Epoch 150/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4820e-04 - val_mean_squared_error: 6.4820e-04
# Epoch 151/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4637e-04 - val_mean_squared_error: 6.4637e-04
# Epoch 152/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5322e-04 - val_mean_squared_error: 6.5322e-04
# Epoch 153/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4336e-04 - val_mean_squared_error: 6.4336e-04
# Epoch 154/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4766e-04 - val_mean_squared_error: 6.4766e-04
# Epoch 155/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4519e-04 - val_mean_squared_error: 6.4519e-04
# Epoch 156/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4306e-04 - val_mean_squared_error: 6.4306e-04
# Epoch 157/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5130e-04 - val_mean_squared_error: 6.5130e-04
# Epoch 158/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4406e-04 - val_mean_squared_error: 6.4406e-04
# Epoch 159/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5904e-04 - val_mean_squared_error: 6.5904e-04
# Epoch 160/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4680e-04 - val_mean_squared_error: 6.4680e-04
# Epoch 161/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4494e-04 - val_mean_squared_error: 6.4494e-04
# Epoch 162/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4812e-04 - val_mean_squared_error: 6.4812e-04
# Epoch 163/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4159e-04 - val_mean_squared_error: 6.4159e-04
# Epoch 164/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4430e-04 - val_mean_squared_error: 6.4430e-04
# Epoch 165/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4219e-04 - val_mean_squared_error: 6.4219e-04
# Epoch 166/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3862e-04 - val_mean_squared_error: 6.3862e-04
# Epoch 167/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3719e-04 - val_mean_squared_error: 6.3719e-04
# Epoch 168/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4065e-04 - val_mean_squared_error: 6.4065e-04
# Epoch 169/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4215e-04 - val_mean_squared_error: 6.4215e-04
# Epoch 170/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3905e-04 - val_mean_squared_error: 6.3905e-04
# Epoch 171/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3958e-04 - val_mean_squared_error: 6.3958e-04
# Epoch 172/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4089e-04 - val_mean_squared_error: 6.4089e-04
# Epoch 173/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4019e-04 - val_mean_squared_error: 6.4019e-04
# Epoch 174/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4148e-04 - val_mean_squared_error: 6.4148e-04
# Epoch 175/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4014e-04 - val_mean_squared_error: 6.4014e-04
# Epoch 176/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3991e-04 - val_mean_squared_error: 6.3991e-04
# Epoch 177/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3842e-04 - val_mean_squared_error: 6.3842e-04
# Epoch 178/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3908e-04 - val_mean_squared_error: 6.3908e-04
# Epoch 179/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3845e-04 - val_mean_squared_error: 6.3845e-04
# Epoch 180/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.5169e-04 - val_mean_squared_error: 6.5169e-04
# Epoch 181/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3972e-04 - val_mean_squared_error: 6.3972e-04
# Epoch 182/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3723e-04 - val_mean_squared_error: 6.3723e-04
# Epoch 183/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4175e-04 - val_mean_squared_error: 6.4175e-04
# Epoch 184/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4116e-04 - val_mean_squared_error: 6.4116e-04
# Epoch 185/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.3553e-04 - val_mean_squared_error: 6.3553e-04
# Epoch 186/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3592e-04 - val_mean_squared_error: 6.3592e-04
# Epoch 187/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3944e-04 - val_mean_squared_error: 6.3944e-04
# Epoch 188/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4536e-04 - val_mean_squared_error: 6.4536e-04
# Epoch 189/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4347e-04 - val_mean_squared_error: 6.4347e-04
# Epoch 190/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3885e-04 - val_mean_squared_error: 6.3885e-04
# Epoch 191/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3400e-04 - val_mean_squared_error: 6.3400e-04
# Epoch 192/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4030e-04 - val_mean_squared_error: 6.4030e-04
# Epoch 193/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4109e-04 - val_mean_squared_error: 6.4109e-04
# Epoch 194/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3886e-04 - val_mean_squared_error: 6.3886e-04
# Epoch 195/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3932e-04 - val_mean_squared_error: 6.3932e-04
# Epoch 196/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3456e-04 - val_mean_squared_error: 6.3456e-04
# Epoch 197/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3732e-04 - val_mean_squared_error: 6.3732e-04
# Epoch 198/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3561e-04 - val_mean_squared_error: 6.3561e-04
# Epoch 199/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3732e-04 - val_mean_squared_error: 6.3732e-04
# Epoch 200/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3842e-04 - val_mean_squared_error: 6.3842e-04
# Epoch 201/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3518e-04 - val_mean_squared_error: 6.3518e-04
# Epoch 202/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4971e-04 - val_mean_squared_error: 6.4971e-04
# Epoch 203/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4805e-04 - val_mean_squared_error: 6.4805e-04
# Epoch 204/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3731e-04 - val_mean_squared_error: 6.3731e-04
# Epoch 205/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3258e-04 - val_mean_squared_error: 6.3258e-04
# Epoch 206/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.3234e-04 - val_mean_squared_error: 6.3234e-04
# Epoch 207/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.4303e-04 - val_mean_squared_error: 6.4303e-04
# Epoch 208/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3212e-04 - val_mean_squared_error: 6.3212e-04
# Epoch 209/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3465e-04 - val_mean_squared_error: 6.3465e-04
# Epoch 210/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.3116e-04 - val_mean_squared_error: 6.3116e-04
# Epoch 211/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3352e-04 - val_mean_squared_error: 6.3352e-04
# Epoch 212/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.3959e-04 - val_mean_squared_error: 6.3959e-04
# Epoch 213/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3552e-04 - val_mean_squared_error: 6.3552e-04
# Epoch 214/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.3432e-04 - val_mean_squared_error: 6.3432e-04
# Epoch 215/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3596e-04 - val_mean_squared_error: 6.3596e-04
# Epoch 216/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.2980e-04 - val_mean_squared_error: 6.2980e-04
# Epoch 217/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.4095e-04 - val_mean_squared_error: 6.4095e-04
# Epoch 218/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3596e-04 - val_mean_squared_error: 6.3596e-04
# Epoch 219/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3220e-04 - val_mean_squared_error: 6.3220e-04
# Epoch 220/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3074e-04 - val_mean_squared_error: 6.3074e-04
# Epoch 221/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3911e-04 - val_mean_squared_error: 6.3911e-04
# Epoch 222/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3690e-04 - val_mean_squared_error: 6.3690e-04
# Epoch 223/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.3106e-04 - val_mean_squared_error: 6.3106e-04
# Epoch 224/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3614e-04 - val_mean_squared_error: 6.3614e-04
# Epoch 225/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3204e-04 - val_mean_squared_error: 6.3204e-04
# Epoch 226/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.3073e-04 - val_mean_squared_error: 6.3073e-04
# Epoch 227/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.3857e-04 - val_mean_squared_error: 6.3857e-04
# Epoch 228/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.3013e-04 - val_mean_squared_error: 6.3013e-04
# Epoch 229/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3791e-04 - val_mean_squared_error: 6.3791e-04
# Epoch 230/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.2789e-04 - val_mean_squared_error: 6.2789e-04
# Epoch 231/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3426e-04 - val_mean_squared_error: 6.3426e-04
# Epoch 232/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3410e-04 - val_mean_squared_error: 6.3410e-04
# Epoch 233/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.6195e-04 - val_mean_squared_error: 6.6195e-04
# Epoch 234/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3760e-04 - val_mean_squared_error: 6.3760e-04
# Epoch 235/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.2926e-04 - val_mean_squared_error: 6.2926e-04
# Epoch 236/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3563e-04 - val_mean_squared_error: 6.3563e-04
# Epoch 237/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.2893e-04 - val_mean_squared_error: 6.2893e-04
# Epoch 238/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.3633e-04 - val_mean_squared_error: 6.3633e-04
# Epoch 239/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.2794e-04 - val_mean_squared_error: 6.2794e-04
# Epoch 240/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.3059e-04 - val_mean_squared_error: 6.3059e-04
# Epoch 241/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.4147e-04 - val_mean_squared_error: 6.4147e-04
# Epoch 242/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3008e-04 - val_mean_squared_error: 6.3008e-04
# Epoch 243/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3426e-04 - val_mean_squared_error: 6.3426e-04
# Epoch 244/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3583e-04 - val_mean_squared_error: 6.3583e-04
# Epoch 245/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.3387e-04 - val_mean_squared_error: 6.3387e-04
# Epoch 246/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.3147e-04 - val_mean_squared_error: 6.3147e-04
# Epoch 247/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.2805e-04 - val_mean_squared_error: 6.2805e-04
# Epoch 248/250
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.3492e-04 - val_mean_squared_error: 6.3492e-04
# Epoch 249/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.3668e-04 - val_mean_squared_error: 6.3668e-04
# Epoch 250/250
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss:
#   0.0006385670858435333,
#   0.000630129303317517,
#   0.0006379111437126994,
#   0.0006278923829086125,
#   0.000634260883089155,
#   0.0006340961554087698,
#   0.0006619512569159269,
#   0.0006375971133820713,
#   0.0006292570615187287,
#   0.000635626376606524,
#   0.0006289263255894184,
#   0.0006363327847793698,
#   0.0006279399967752397,
#   0.0006305857095867395,
#   0.0006414748495444655,
#   0.0006300845416262746,
#   0.0006342550041154027,
#   0.000635828182566911,
#   0.0006338655948638916,
#   0.0006314701167866588,
#   0.0006280498928390443,
#   0.0006349156610667706,
#   0.0006366803427226841,
#   0.0006379288388416171]}

# %%
final_model =srcnn.save('drive/MyDrive/Colab Notebooks/SRCNN/weights.h5')

# %%
# define necessary image processing functions

#necessary cuz when we run images through SRCNN based on the kernel sizes and convulational layers, we are going to lose some of these outside pixels
#the images are going to get smaller and that's why it is neccesary to have a divisible image size 
def modcrop(img,scale):
    #temp size
    tmpsz=img.shape
    sz=tmpsz[0:2]
    
    #ensures that dimension of our image are divisible by scale(doesn't leaves hanging remainders) by cropping the images size
    #np.mod returns the remainder bewtween our sz and scale
    sz=sz-np.mod(sz,scale)
    
    img=img[0:sz[0],1:sz[1]]
    return img

# %%
#crop offs the bordersize from all sides of the image
def shave(image,border):
    img=image[border: -border,border:-border]
    return img

# %%
#define main prediction function

def predict(image_path):
    
    #load the srcnn model with weights cuz deep learning neural n/w take lot of time to train(have to feed in large amount of input data)
    model = model()
    model.load_weights('drive/MyDrive/Colab Notebooks/SRCNN/weights.h5')
    model.fit()
     
    #load the degraded and reference images
    #in opencv, images are loaded as BGR channels
    path,file=os.path.split(image_path)
    degraded=cv2.imread(image_path)
    ref=cv2.imread(r'drive/MyDrive/Colab Notebooks/SRCNN/source/{}'.format(file))
    
    #preprocess the image with modcrop
    ref=modcrop(ref,3)
    #when calculating our image quality metrics later we have the same size image to what we produce in SRCNN network
    degraded=modcrop(degraded,3)
    
    #convert the image to YCrCb(3 channel image) - (srcnn trained on Y channel)
    temp=cv2.cvtColor(degraded,cv2.COLOR_BGR2YCrCb)
    #opencv does a very good job in converting from rgb to YCrCb and back
    
    #create image slice and normalize cuz SRCNN works on one dimensional input(or 3D inputs of depth 1 ,ie, inputs with one channel)
    Y=numpy.zeros((1,temp.shape[0],temp.shape[1],1),dtype=float)
    #create a numpy array the we fill with data,temp.shape[0]=width,[1]=height and last one means one channel(essentially like batch=1 cuz that's what going to get passed to the n/w ')
    #fill in the data; all values are normalized to between 0 and 1 as that's how srcnn was trained
    Y[0,:,:,0]=temp[:,:,0].astype(float)/255
    #first 0 means 0th index(we are saying that batch size is 1); :,: means every point in these channels; last 0 means first channel,ie, all the pixels in first luminescence channel
    #so we have our image slice, we have the Y channel, which is the first channel(index 0) out of the image that we converted to YCrCb color space
    
    #perform super-resolution with srcnn
    pre=srcnn.predict(Y,batch_size=1)#that's why we had index 0  above cuz we are saying that batch size is 1
    
    #post-process output cuz pre is still normalized
    pre*=255#multiplying every pixel by 255
    pre[pre[:]>255]=255#any pixels >255 set it =255 to prevent any rounding errors due to multiplication
    pre[pre[:]<0] =0# same reason as above
    pre=pre.astype(np.uint8)#convert float back to int values
    
    #cuz this is only the luminescence channel in the pre ,SO
    #copy Y channel back to image and convert to BGR
    temp=shave(temp,6)#accd.to tutor it loses 3 pixels on each side so if we shave this with a border 6,we can crop it appropriately there, so it is the same size as our output
    #if not agree with tutor, use print statements to see the specific dimensions
    
    # for the first channel(Y channel), copy in the output of our network
    temp[:,:,0]=pre[0,:,:,0]
    #So we are keeping the red difference and blue difference, channels 1 and 2, in this temp image which is in the YCrCb color space
    #and in the first one we are copying in our ouput,our luminiscence channel
    
    #convert back to bgr
    output=cv2.cvtColor(temp,cv2.COLOR_YCrCb2BGR)
    
    #emove borderfrom reference and degraded image, so that all our images(ref,degraded(low res.), and ouput(high res.))
    #are of the same size
    ref = shave(ref.astype(np.uint8), 6)
    degraded = shave(degraded.astype(np.uint8), 6)
    
    # image quality calculations
    scores = []
    scores.append(compare_images(degraded, ref))#degraded wrt ref
    scores.append(compare_images(output, ref))#high res. output wrt ref
    
    # return images and scores
    return ref, degraded, output, scores

# %%
for file in os.listdir('drive/MyDrive/Colab Notebooks/SRCNN/Set5'):
  # perform super-resolution
  ref, degraded, output, scores = predict('drive/MyDrive/Colab Notebooks/SRCNN/Set5')
 
  # display images as subplots
  fig, axs = plt.subplots(1, 3, figsize=(20, 8))
  axs[0].imshow(cv2.cvtColor(ref, cv2.COLOR_BGR2RGB))
  axs[0].set_title('Original')
  axs[1].imshow(cv2.cvtColor(degraded, cv2.COLOR_BGR2RGB))
  axs[1].set_title('Degraded')
  axs[1].set(xlabel = 'PSNR: {}\nMSE: {} \nSSIM: {}'.format(scores[0][0], scores[0][1], scores[0][2]))
  axs[2].imshow(cv2.cvtColor(output, cv2.COLOR_BGR2RGB))
  axs[2].set_title('SRCNN')
  axs[2].set(xlabel = 'PSNR: {} \nMSE: {} \nSSIM: {}'.format(scores[1][0], scores[1][1], scores[1][2]))
 
  # remove the x and y ticks
  for ax in axs:
      ax.set_xticks([])
      ax.set_yticks([])
print('Total PSNR: {}\nTotal MSE: {} \n'.format(scores[1][0]/5, scores[1][1]/5))
#print('Saving {}'.format(file))
#fig.savefig('output/{}.png'.format(os.path.splitext(file)[0])) 
#plt.close()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-42-6e91297af555> in <module>()
#       1 for file in os.listdir('drive/MyDrive/Colab Notebooks/SRCNN/Set5'):
#       2   # perform super-resolution
# ----> 3   ref, degraded, output, scores = predict('drive/MyDrive/Colab Notebooks/SRCNN/Set5')
#       4
#       5   # display images as subplots
#
# <ipython-input-41-176a94673683> in predict(image_path)
#       4
#       5     #load the srcnn model with weights cuz deep learning neural n/w take lot of time to train(have to feed in large amount of input data)
# ----> 6     model = model()
#       7     model.load_weights('drive/MyDrive/Colab Notebooks/SRCNN/weights.h5')
#       8     model.fit()
#
# UnboundLocalError: local variable 'model' referenced before assignment
